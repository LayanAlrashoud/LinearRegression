# %% [markdown]
# <h2> Linear Regression with one independent varible</h2>
# <h4>Using linear regression to predict the price of a property based on its area</h4>

# %%
import pandas as pd
df = pd.read_excel('areaprice.xlsx')
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
import matplotlib.pyplot as plt
plt.xlabel('area')
plt.ylabel('price')
plt.scatter(df.area,df.price,color="red",marker='*')
plt.plot(df.area,reg.predict(df[['area']]),color='blue')

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(df[['area']],df.price)

reg.predict([[3300]])
# Out:
# c:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# 180616.43835616432
